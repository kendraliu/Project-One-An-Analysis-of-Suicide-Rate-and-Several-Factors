# %%
#Import dependencies
import pandas as pd

# %%
suicide_rates_df = pd.read_csv('master.csv')
    #Import raw CSV data
suicide_rates_df = suicide_rates_df.drop(['country-year',' gdp_for_year ($) '], axis=1)
    #Drop unneccesary columns. In this case we only need columns that have to do with suicide, generation, and HDI
suicide_rates_df = suicide_rates_df[suicide_rates_df['year'] == 2020]
    #To keep the data consistent, we only look at data from the year 2020.
suicide_rates_df = suicide_rates_df.dropna()
    #Using .dropna we remove any rows with incomplete values
suicide_rates_df.to_csv('cleaned_df.csv')
    #Name and save cleaned CSV
suicide_rates_df
# Out:
#                         country  year     sex         age  suicides_no  \
# 27823                 Australia  2020    male  5-14 years         15.0
# 27824                   Austria  2020    male  5-14 years          2.0
# 27834                Costa Rica  2020    male  5-14 years          1.0
# 27838                   Czechia  2020    male  5-14 years          3.0
# 27841                   Ecuador  2020    male  5-14 years         44.0
# ...                         ...   ...     ...         ...          ...
# 31493                    Serbia  2020  female   75+ years         62.0
# 31495                 Singapore  2020  female   75+ years         18.0
# 31497                  Slovenia  2020  female   75+ years         24.0
# 31499                     Spain  2020  female   75+ years        182.0
# 31507  United States of America  2020  female   75+ years        521.0
#
#        population  suicides/100k pop  HDI for year  gdp_per_capita ($)  \
# ...
